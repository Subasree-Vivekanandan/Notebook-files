# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
heart_data = pd.read_csv(r"C:\Users\HP\Notebook files\heart-disease.csv")
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_series= heart_data["age"]
type(heart_series)
# Out:
# pandas.core.series.Series

# %%
heart_series
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
updated_heartdisease = heart_data.to_csv("updated_heart_disease.csv")
updated_heartdisease

# %% [markdown]
# ## describe data

# %% [markdown]
# ## attributes

# %%
heart_data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
heart_columns = heart_data.columns
heart_columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart_data.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %% [markdown]
# ## functions

# %% [markdown]
# describe works on only numeric columns

# %%
heart_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# average of values applies only on numeric values
heart_data.mean()
# Out:
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %%
 heart_data.sum()
# Out:
# age         16473.0
# sex           207.0
# cp            293.0
# trestbps    39882.0
# chol        74618.0
# fbs            45.0
# restecg       160.0
# thalach     45343.0
# exang          99.0
# oldpeak       315.0
# slope         424.0
# ca            221.0
# thal          701.0
# target        165.0
# dtype: float64

# %%
heart_data["chol"].sum()
# Out:
# 74618

# %%
# len -> rows in dataframe
len(heart_data)
# Out:
# 303

# %%
heart_data.ndim
# Out:
# 2

# %% [markdown]
# ## viewing and selecting data

# %%
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_data.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
# .loc[] and iloc[]

series = pd.Series(["apple","banana","berry","orange"],index=[0,3,4,3])
series
# Out:
# 0     apple
# 3    banana
# 4     berry
# 3    orange
# dtype: object

# %%
# loc[] refers index numbers
series.loc[3]
# Out:
# 3    banana
# 3    orange
# dtype: object

# %%
# .iloc[] refers to position

series.iloc[3]
# Out:
# 'orange'

# %%
heart_data.loc[3]
# Out:
# age          56.0
# sex           1.0
# cp            1.0
# trestbps    120.0
# chol        236.0
# fbs           0.0
# restecg       1.0
# thalach     178.0
# exang         0.0
# oldpeak       0.8
# slope         2.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 3, dtype: float64

# %%
heart_data.head(7)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
heart_data.iloc[3]
# Out:
# age          56.0
# sex           1.0
# cp            1.0
# trestbps    120.0
# chol        236.0
# fbs           0.0
# restecg       1.0
# thalach     178.0
# exang         0.0
# oldpeak       0.8
# slope         2.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 3, dtype: float64

# %%
heart_data.iloc[[1,20,40,100]]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1     37    1   2       130   250    0        1      187      0      3.5
# 20    59    1   0       135   234    0        1      161      0      0.5
# 40    51    0   2       140   308    0        0      142      0      1.5
# 100   42    1   3       148   244    0        0      178      0      0.8
#
#      slope  ca  thal  target
# 1        0   0     2       1
# 20       1   0     3       1
# 40       2   1     2       1
# 100      2   2     2       1

# %%
heart_data.loc[[1,20,40,100]]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1     37    1   2       130   250    0        1      187      0      3.5
# 20    59    1   0       135   234    0        1      161      0      0.5
# 40    51    0   2       140   308    0        0      142      0      1.5
# 100   42    1   3       148   244    0        0      178      0      0.8
#
#      slope  ca  thal  target
# 1        0   0     2       1
# 20       1   0     3       1
# 40       2   1     2       1
# 100      2   2     2       1

# %%
# slicing in .loc[] includes the upper bound as well
heart_data.loc[3:5]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
#
#    ca  thal  target
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1

# %%
# slicing in .iloc[] does not include the upper bound
heart_data.iloc[3:5]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 3   0     2       1
# 4   0     2       1

# %%
# selecting a column

heart_data["age"]
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
#selecting a column using dataframe.column_name (if your column name has a space this wont work)
heart_data.age
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
# select a single column with filter

heart_data["age"] > 50
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 298     True
# 299    False
# 300     True
# 301     True
# 302     True
# Name: age, Length: 303, dtype: bool

# %%
heart_data[heart_data["age"] > 70]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 25    71    0   1       160   302    0        1      162      0      0.4
# 60    71    0   2       110   265    1        0      130      0      0.0
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 151   71    0   0       112   149    0        1      125      0      1.6
# 238   77    1   0       125   304    0        0      162      1      0.0
#
#      slope  ca  thal  target
# 25       2   2     2       1
# 60       2   1     2       1
# 129      2   1     2       1
# 144      1   0     2       1
# 151      1   0     2       1
# 238      2   3     2       0

# %%
heart_data[(heart_data["age"] > 70) & (heart_data["sex"]==1)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 238   77    1   0       125   304    0        0      162      1      0.0
#
#      slope  ca  thal  target
# 238      2   3     2       0

# %%
heart_data[(heart_data["age"] > 50) | (heart_data["chol"] < 300)].head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
car_data = pd.read_csv("car-sales.csv")
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_data["Make"],car_data["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_data.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_data.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_data["Odometer (KM)"].plot(figsize=(3,3))
plt.show()

# %%
car_data["Odometer (KM)"].hist(figsize=(3,3))
# Out:
# <AxesSubplot:>

# %%
list(car_data["Odometer (KM)"])
# Out:
# [150043, 87899, 32549, 11179, 213095, 99213, 45698, 54738, 60000, 31600]

# %%
# histogram says that most of the cars lie between the range of 30000 to 120000

# %%
# find how many cars are within the range 300000 and less than 120000 
car_data["Make"][(car_data["Odometer (KM)"] >30000) & (car_data["Odometer (KM)"] < 120000)].count()
# Out:
# 7

# %%
# 7 out of 9 cars

# %%
car_data.Price.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14328\3516020064.py in <module>
# ----> 1 car_data.Price.plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     325     def generate(self):
# ...

# %%
car_data["Price"] = car_data["Price"].str.replace('[\$\,\.]','').astype(int)

# %%
car_data["Price"].dtype
# Out:
# dtype('int32')

# %%
car_data.Price.plot(figsize=(3,3)) # however this is false since 4,000.00 is replaced as 400000
plt.show()

# %%
car_data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000

# %% [markdown]
# ## manipulating data

# %%
car_data["Make"].str.lower() # this will not make changes in the original dataframe

# to save changes assign it like car_data["Make"] = car_data["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
# this indicates that we dont have any missing values in our dataframe
heart_data.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
car_sales_missing = pd.read_csv("car-sales-extended-missing-data.csv")
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing.isna().sum()
# Out:
# Make             49
# Colour           50
# Odometer (KM)    50
# Doors            50
# Price            50
# dtype: int64

# %%
car_sales_missing["Make"].fillna(method="ffill")
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996    Toyota
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales_missing.iloc[996] # no effect on original dataframe
# Out:
# Make                  NaN
# Colour              White
# Odometer (KM)    155144.0
# Doors                 3.0
# Price              5716.0
# Name: 996, dtype: object

# %%
car_sales_missing.Make.fillna(method="ffill",inplace=True) # using forward fill & inplace

# %%
car_sales_missing.iloc[996] # use inplace=True to make chanes to original dataframe
# Out:
# Make               Toyota
# Colour              White
# Odometer (KM)    155144.0
# Doors                 3.0
# Price              5716.0
# Name: 996, dtype: object

# %%
car_sales_missing.isna().sum() # Make column has no NaN entries
# Out:
# Make              0
# Colour           50
# Odometer (KM)    50
# Doors            50
# Price            50
# dtype: int64

# %%
# reassigning to load original dataframe 
car_sales_missing = pd.read_csv("car-sales-extended-missing-data.csv")
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
# we can even drop values with NaN ex: row 996
car_sales_missing.dropna(inplace = True)

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [773 rows x 5 columns]

# %%
car_sales_missing.loc[996] # throws key error since row with index 996 is deleted
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 996
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# dropping all the Nan values

car_sales_missing = pd.read_csv("car-sales-extended-missing-data.csv")
car_sales_missing.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0

# %%
car_sales_missing.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
car_sales_missing.shape # Before dropping 1000 rows , 5 cols
# Out:
# (1000, 5)

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing.shape # AFter dropping 773 rows , cols will remain the same
# Out:
# (773, 5)

# %%
# Creating a column from Series

# %%
windows = pd.Series([4,5,6,4])
car_sales_missing["window"]=windows
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  window
# 0     Honda  White        35431.0    4.0  15323.0     4.0
# 1       BMW   Blue       192714.0    5.0  19943.0     5.0
# 2     Honda  White        84714.0    4.0  28343.0     6.0
# 3    Toyota  White       154365.0    4.0  13434.0     4.0
# 4    Nissan   Blue       181577.0    3.0  14043.0     NaN
# ..      ...    ...            ...    ...      ...     ...
# 994     BMW   Blue       163322.0    3.0  31666.0     NaN
# 995  Toyota  Black        35820.0    4.0  32042.0     NaN
# 997  Nissan   Blue        66604.0    4.0  31570.0     NaN
# 998   Honda  White       215883.0    4.0   4001.0     NaN
# 999  Toyota   Blue       248360.0    4.0  12732.0     NaN
#
# [773 rows x 6 columns]

# %%
car_sales_missing.window.fillna(method="ffill",inplace=True)

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  window
# 0     Honda  White        35431.0    4.0  15323.0     4.0
# 1       BMW   Blue       192714.0    5.0  19943.0     5.0
# 2     Honda  White        84714.0    4.0  28343.0     6.0
# 3    Toyota  White       154365.0    4.0  13434.0     4.0
# 4    Nissan   Blue       181577.0    3.0  14043.0     4.0
# ..      ...    ...            ...    ...      ...     ...
# 994     BMW   Blue       163322.0    3.0  31666.0     4.0
# 995  Toyota  Black        35820.0    4.0  32042.0     4.0
# 997  Nissan   Blue        66604.0    4.0  31570.0     4.0
# 998   Honda  White       215883.0    4.0   4001.0     4.0
# 999  Toyota   Blue       248360.0    4.0  12732.0     4.0
#
# [773 rows x 6 columns]

# %%
# create new column from list

# %%
Rating = [5,7,8.3,5.9,7.3,9]
car_sales_missing["Rating"]=Rating  # length of the list should exactly match the number of row entries
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14328\2719960333.py in <module>
#       1 Rating = [5,7,8.3,5.9,7.3,9]
# ----> 2 car_sales_missing["Rating"]=Rating  # length of the list should exactly match the number of row entries
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4536
# ...

# %%
# Create column from single values

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  window
# 0     Honda  White        35431.0    4.0  15323.0     4.0
# 1       BMW   Blue       192714.0    5.0  19943.0     5.0
# 2     Honda  White        84714.0    4.0  28343.0     6.0
# 3    Toyota  White       154365.0    4.0  13434.0     4.0
# 4    Nissan   Blue       181577.0    3.0  14043.0     4.0
# ..      ...    ...            ...    ...      ...     ...
# 994     BMW   Blue       163322.0    3.0  31666.0     4.0
# 995  Toyota  Black        35820.0    4.0  32042.0     4.0
# 997  Nissan   Blue        66604.0    4.0  31570.0     4.0
# 998   Honda  White       215883.0    4.0   4001.0     4.0
# 999  Toyota   Blue       248360.0    4.0  12732.0     4.0
#
# [773 rows x 6 columns]

# %%
car_sales_missing["wheels"] = 4

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  window  wheels
# 0     Honda  White        35431.0    4.0  15323.0     4.0       4
# 1       BMW   Blue       192714.0    5.0  19943.0     5.0       4
# 2     Honda  White        84714.0    4.0  28343.0     6.0       4
# 3    Toyota  White       154365.0    4.0  13434.0     4.0       4
# 4    Nissan   Blue       181577.0    3.0  14043.0     4.0       4
# ..      ...    ...            ...    ...      ...     ...     ...
# 994     BMW   Blue       163322.0    3.0  31666.0     4.0       4
# 995  Toyota  Black        35820.0    4.0  32042.0     4.0       4
# 997  Nissan   Blue        66604.0    4.0  31570.0     4.0       4
# 998   Honda  White       215883.0    4.0   4001.0     4.0       4
# 999  Toyota   Blue       248360.0    4.0  12732.0     4.0       4
#
# [773 rows x 7 columns]

# %%
car_sales_missing["Passed road safety (L)"] =True
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  window  wheels  \
# 0     Honda  White        35431.0    4.0  15323.0     4.0       4
# 1       BMW   Blue       192714.0    5.0  19943.0     5.0       4
# 2     Honda  White        84714.0    4.0  28343.0     6.0       4
# 3    Toyota  White       154365.0    4.0  13434.0     4.0       4
# 4    Nissan   Blue       181577.0    3.0  14043.0     4.0       4
# ..      ...    ...            ...    ...      ...     ...     ...
# 994     BMW   Blue       163322.0    3.0  31666.0     4.0       4
# 995  Toyota  Black        35820.0    4.0  32042.0     4.0       4
# 997  Nissan   Blue        66604.0    4.0  31570.0     4.0       4
# 998   Honda  White       215883.0    4.0   4001.0     4.0       4
# 999  Toyota   Blue       248360.0    4.0  12732.0     4.0       4
#
#      Passed road safety  Passed road safety (L)
# 0                  True                    True
# 1                  True                    True
# ...

# %%
# drop a column

# %%
car_sales_missing.drop("Passed road safety",axis=1,inplace=True) # specify axis to mention that "Passed road safety" is a column

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  window  wheels  \
# 0     Honda  White        35431.0    4.0  15323.0     4.0       4
# 1       BMW   Blue       192714.0    5.0  19943.0     5.0       4
# 2     Honda  White        84714.0    4.0  28343.0     6.0       4
# 3    Toyota  White       154365.0    4.0  13434.0     4.0       4
# 4    Nissan   Blue       181577.0    3.0  14043.0     4.0       4
# ..      ...    ...            ...    ...      ...     ...     ...
# 994     BMW   Blue       163322.0    3.0  31666.0     4.0       4
# 995  Toyota  Black        35820.0    4.0  32042.0     4.0       4
# 997  Nissan   Blue        66604.0    4.0  31570.0     4.0       4
# 998   Honda  White       215883.0    4.0   4001.0     4.0       4
# 999  Toyota   Blue       248360.0    4.0  12732.0     4.0       4
#
#      Passed road safety (L)
# 0                      True
# 1                      True
# 2                      True
# 3                      True
# ...

# %%
# shuffle columns using sample() in pandas

# %%
# randomize the order of data -> useful when we seperate train,validate,test data

# %%
car_data_shuffle  = car_sales_missing.sample(frac=0.5)  # fraction data to be shuffled
car_data_shuffle
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  window  wheels  \
# 879   Honda   Blue       236760.0    4.0  12362.0     4.0       4
# 862   Honda   Blue        40635.0    4.0  12402.0     4.0       4
# 973   Honda  Green       237627.0    4.0   8430.0     4.0       4
# 566   Honda  White        42844.0    4.0  29145.0     4.0       4
# 920  Nissan  White        19134.0    4.0  23439.0     4.0       4
# ..      ...    ...            ...    ...      ...     ...     ...
# 332  Nissan   Blue       195494.0    4.0   6460.0     4.0       4
# 81   Toyota   Blue        34097.0    4.0  20142.0     4.0       4
# 439  Toyota  Black        59249.0    4.0   9108.0     4.0       4
# 367   Honda  White        34822.0    4.0  14613.0     4.0       4
# 352   Honda    Red        47933.0    4.0  10301.0     4.0       4
#
#      Passed road safety (L)
# 879                    True
# 862                    True
# 973                    True
# 566                    True
# ...

# %%
car_data_shuffle.reset_index() # adds old index as a column
# Out:
#      index    Make Colour  Odometer (KM)  Doors    Price  window  wheels  \
# 0      879   Honda   Blue       236760.0    4.0  12362.0     4.0       4
# 1      862   Honda   Blue        40635.0    4.0  12402.0     4.0       4
# 2      973   Honda  Green       237627.0    4.0   8430.0     4.0       4
# 3      566   Honda  White        42844.0    4.0  29145.0     4.0       4
# 4      920  Nissan  White        19134.0    4.0  23439.0     4.0       4
# ..     ...     ...    ...            ...    ...      ...     ...     ...
# 381    332  Nissan   Blue       195494.0    4.0   6460.0     4.0       4
# 382     81  Toyota   Blue        34097.0    4.0  20142.0     4.0       4
# 383    439  Toyota  Black        59249.0    4.0   9108.0     4.0       4
# 384    367   Honda  White        34822.0    4.0  14613.0     4.0       4
# 385    352   Honda    Red        47933.0    4.0  10301.0     4.0       4
#
#      Passed road safety (L)
# 0                      True
# 1                      True
# ...

# %%
car_data_shuffle.reset_index(drop=True,inplace=True)

# %%
car_data_shuffle # dataframe with new indexes
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  window  wheels  \
# 0     Honda   Blue       236760.0    4.0  12362.0     4.0       4
# 1     Honda   Blue        40635.0    4.0  12402.0     4.0       4
# 2     Honda  Green       237627.0    4.0   8430.0     4.0       4
# 3     Honda  White        42844.0    4.0  29145.0     4.0       4
# 4    Nissan  White        19134.0    4.0  23439.0     4.0       4
# ..      ...    ...            ...    ...      ...     ...     ...
# 381  Nissan   Blue       195494.0    4.0   6460.0     4.0       4
# 382  Toyota   Blue        34097.0    4.0  20142.0     4.0       4
# 383  Toyota  Black        59249.0    4.0   9108.0     4.0       4
# 384   Honda  White        34822.0    4.0  14613.0     4.0       4
# 385   Honda    Red        47933.0    4.0  10301.0     4.0       4
#
#      Passed road safety (L)
# 0                      True
# 1                      True
# 2                      True
# 3                      True
# ...

# %%
#export new csv to our directory
car_sample_new_indexed = car_data_shuffle.to_csv("car_sample_new_indexed.csv")

# %%
# applying function to a column

# %%
car_data["Price"] = car_data["Price"].apply(lambda x: x/100)

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
# export updated file

# %%
updated_car_data = car_data.to_csv("updated_car_data.csv")
